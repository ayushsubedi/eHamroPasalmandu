# %%
from faker import Faker
fake = Faker(['ne_NP', 'en_US'])

# %%
names = [fake.unique.name() for i in range(500)]

# %%
names
# Out:
# ['Megan Choi',
#  'सुश्री निरजा मानन्धर',
#  'चण्डिका रेग्मी',
#  'शाहिद महर्जन',
#  'पूर्णमाया पौड्याल',
#  'सुश्री ज्ञानी शर्मा',
#  'James Stewart',
#  'Michael Grimes',
#  'Gabrielle Morris',
#  'Logan Smith',
#  'Angela Hill',
#  'Shawn Murphy',
#  'निरा सिंह',
#  'श्री कल्याण श्रेष्\u200dठ',
#  'हिरा न्यौपाने',
#  'Joseph Jones',
#  'John Jones',
#  'Amy Camacho',
#  'राजु महर्जन',
#  'Kelly Bennett',
#  'Harry Morris',
#  'नारायण प्रजापति',
#  'उज्ज्वल शाह',
#  'Haley Freeman',
#  'प्रजीत श्रेष्\u200dठ',
#  'श्याम क्षेत्री',
#  'Alison Chavez',
#  'सुश्री विष्\u200dणु श्रेष्\u200dठ',
#  'श्री अशोक गुरुङ्ग',
#  'Kelsey Downs',
#  'सफराज पाण्डे',
#  'Carla Shah',
#  'William Davis',
#  'रविश्री खनाल',
#  'Erik Brown',
#  'इच्छा अग्रवाल',
#  'शाहिद हायाजु',
#  'सुश्री निम्मी गुरुङ्ग',
#  'Robert Reed',
#  'प्रफुल्ल अग्रवाल',
#  'सृजना दुगड',
#  'सुरेश लामा',
#  'Susan Norman',
#  'सुश्री सुरेन्\u200dद्रा श्रेष्\u200dठ',
#  'Ashley Miller',
#  'मिना महर्जन',
#  'शान्ता सिंह',
#  'Kevin Lewis',
#  'Shawn Cannon',
#  'Jamie Freeman',
#  'मीना श्रेष्\u200dठ',
#  'Tiffany Cruz',
#  'भवानी के.सी.',
#  'सरिता लामा',
#  'अमित भट्टराई',
#  'Ashlee Hendricks',
#  'Abigail Berry',
#  'रोजिन (पाण्डे)',
#  'माधुरी मोक्तान',
#  'Stacy Murphy',
#  'Carla Cohen',
#  'कृष्\u200dण मानन्धर',
#  'केशव मल्ल',
#  'राम थापा',
#  'Monique Roberts',
#  'Michael Powers',
#  'Thomas Sosa',
#  'Calvin Fischer',
#  'अनुरा तिवारी',
#  'Donna Foley',
#  'Monica Gross',
#  'Julie Ortega',
#  'सलिमा मोक्तान',
#  'James Collins',
#  'तेजस्वी अधिकारी',
#  'Lynn Casey',
#  'शोभा घिमिरे',
#  'चैत्य बस्नेत',
#  'Kristen Long',
#  'श्रीमती मल्लीका अग्रवाल',
#  'दिलिप राठौर',
#  'Gerald Fletcher',
#  'Ryan Mcfarland',
#  'Miss Jody Davis',
#  'एक नेपाली',
#  'सचिता श्रेष्\u200dठ',
#  'रोजिना शाह',
#  'Vanessa Myers',
#  'रश्\u200dमी शाह',
#  'Eric Bates',
#  'देवेन्द्र लामा',
#  'Michelle Vance',
#  'दिपक सापकोटा',
#  'John Kim',
#  'Derrick Melendez',
#  'William Fernandez',
#  'नारायण पाण्\u200dडे',
#  'मैया श्रेष्\u200dठ',
#  'रबीना पाण्डे',
#  'Tracey Gonzalez',
#  'सुरेश डंगोल',
#  'Isabella Mccarty',
#  'Victor Hamilton',
#  'रेखा अग्रवाल',
#  'काजी शेर्पा',
#  'Patrick Crane',
#  'Stephanie Anderson',
#  'Steven Reyes',
#  'Jonathan Wagner',
#  'Claire Marks',
#  'सजन गौतम',
#  'श्रीमती शशी डंगोल',
#  'श्रीमती ज्यास्मीन मल्ल',
#  'Thomas Moore',
#  'श्री सफराज राजकर्णिकार',
#  'Megan Garcia',
#  'Jeremy Contreras',
#  'Jane Bradley',
#  'अशोक रेग्मी',
#  'Taylor Cole',
#  'Chelsea Allen',
#  'जगन्नाथ मानन्धर',
#  'Christopher Miller',
#  'Tyler Boyle',
#  'अरुणा प्\u200dयाकुरेल',
#  'Brandon Smith',
#  'Alexander Sullivan',
#  'Terry Garcia',
#  'Larry Brown',
#  'शुशिला लोहनी',
#  'Justin Martinez',
#  'मनोज पाण्\u200dडे',
#  'Donna Wang',
#  'Loretta Brewer',
#  'Adam Martinez',
#  'मालचन्द टिब्रेवाल',
#  'महावती पाण्डे',
#  'Kayla Mejia',
#  'James Jones',
#  'श्रद्धा श्रेष्\u200dठ',
#  'जगनाथ शाह',
#  'Megan Johnson',
#  'रुजा सिंह',
#  'प्रसङ्ग आलम',
#  'श्रीमान निमेश शेर्पा',
#  'रेणु महर्जन',
#  'Joshua Curry',
#  'निम्मी रेग्\u200dमी',
#  'Benjamin Kemp',
#  'Jesus Smith',
#  'Mr. William Wolfe',
#  'नानु श्रेष्\u200dठ',
#  'चम्पा पनेरु',
#  'Andrew Casey',
#  'श्रीमती धर्म रिमाल',
#  'केशव गुप्\u200dता',
#  'Crystal Lutz',
#  'Katherine Clark',
#  'Dale Brooks',
#  'Sarah Jackson',
#  'Rachel Parker',
#  'Zachary Harrison',
#  'शरद पाण्डे',
#  'श्रीमती अमृता मित्तल',
#  'Mark Wong',
#  'Richard Hodges',
#  'Dominic Smith',
#  'Kathryn Dunn',
#  'Melissa Ford',
#  'प्रफुल्ल गुरागाई',
#  'अनिल अग्रवाल',
#  'कमला श्रेष्\u200dठ',
#  'श्रीया सिलवाल',
#  'सुजन मानन्धर',
#  'सपना खत्री',
#  'छुङड्याक गुरागाई',
#  'Rachel Hester',
#  'Linda Shaw',
#  'Carlos Lopez PhD',
#  'Jonathan Torres',
#  'जगन्नाथ गुरुङ',
#  'इशु ढुङ्गेल',
#  'Tracey Callahan',
#  'राम के.सी',
#  'जयन्द्र अग्रवाल',
#  'ज्ञानु अग्रवाल',
#  'कुशल लोहनी',
#  'Whitney Harris',
#  'खगेन्द्र श्रेष्ठ',
#  'सविता कक्षपती',
#  'William Brady',
#  'रजनी भट्टराई',
#  'Dr. Catherine Jenkins MD',
#  'Julia Gomez',
#  'विनिल भिमसरिया',
#  'Christopher Li',
#  'Robin Wilkinson',
#  'Cheryl Christian',
#  'रविन्द्र मानन्धर',
#  'ऋषिकेस श्रेष्\u200dठ',
#  'जयराम शाह',
#  'Steven Pearson',
#  'Dawn Rojas',
#  'गायत्री शेर्पा',
#  'Sarah Olson',
#  'शर्मिला लोहनी',
#  'रुपेश शाक्य',
#  'Gabrielle Gonzales',
#  'Nathan Harris',
#  'श्रीमान नारायण प्रजापति',
#  'छिरिङ जोशी',
#  'संगीता मल्\u200dल',
#  'Ryan Oliver',
#  'अनिता श्रेष्ठ',
#  'Andrew Braun',
#  'Robert Fields',
#  'अम्वीका नेपाली',
#  'दावा राजकर्णिकार',
#  'Nicole Reyes',
#  'ज्ञानहेरा श्रेष्ठ',
#  'निकिता प्रधानाङ्ग',
#  'फुलावती गिरी',
#  'सागर के.सी',
#  'सुश्री अनिता ठकुरी',
#  'Amanda Smith',
#  'Joel Perkins',
#  'Vincent Turner MD',
#  'टासी के.सी',
#  'श्री महेश पाण्डे',
#  'उषा खनाल',
#  'जुनु सत्याल',
#  'प्रमेश्\u200dवर अग्रवाल',
#  'Sharon Joseph',
#  'सरिता (पाण्डे)',
#  'चम्पा जैन',
#  'Jenny Gibson',
#  'Stephanie Riggs',
#  'जुनु उपाध्याय',
#  'Matthew Johnson',
#  'सानु थापा',
#  'अलंकार के.सी.',
#  'निरोज न्यौपाने',
#  'शिखा ढुङ्गेल',
#  'Kristine Smith',
#  'Michael Clark',
#  'विनोद गुरुङ्ग',
#  'स्वागत शाह',
#  'किशन शाक्य',
#  'छिरिङ हायजु',
#  'राजु पाण्डेय',
#  'श्री सुनिल मानन्धर',
#  'James Morton',
#  'Joyce Sanders',
#  'श्रीमान सुन्दर मल्ल',
#  'Charles Martinez',
#  'Nancy Day',
#  'संजय श्रेष्\u200dठ',
#  'Lisa Turner',
#  'John Garcia',
#  'Mr. Jesus Simpson',
#  'अनिर गुरुङ्ग',
#  'Cory Christensen',
#  'Richard Spencer',
#  'सुश्री मेरिना खड्गी',
#  'श्री बिकाश श्रेष्\u200dठ',
#  'Amy Pace',
#  'Elijah Brown',
#  'Robert Hughes',
#  'Brian Moreno',
#  'पूर्ण तिवारी',
#  'बलराम कंसाकार',
#  'सुश्री रजिता नेपाल',
#  'गंगा गुरुङ्ग',
#  'Thomas Reynolds',
#  'राम श्रेष्\u200dठ',
#  'संगिता गुरागाई',
#  'Aaron Sanchez',
#  'Craig Wilcox',
#  'समीना उपाध्याय',
#  'दिपिसा श्रेष्\u200dठ',
#  'धन्जु महर्जन',
#  'शुभेच्छा पौडेल',
#  'कृष्\u200dण मित्तल',
#  'Michael Robinson',
#  'Judith Alvarado',
#  'Michael Rocha',
#  'सेखर सिंह',
#  'Jessica Rollins',
#  'Patricia Vazquez',
#  'श्री राम श्रेष्ठ',
#  'सावित्री नेपाल',
#  'Victoria Dixon',
#  'अनिता अग्रवाल',
#  'Cynthia Montes',
#  'Kayla Lewis',
#  'रितु थापा',
#  'ईश्\u200dवरी पन्त',
#  'श्रीमती अंगुर राजकर्णिकार',
#  'Cheryl Ward',
#  'Johnathan Fox',
#  'आशा शर्मा',
#  'निरा पराजुली',
#  'श्रीमान निरज जैन',
#  'Kimberly Phillips',
#  'Alvin Nguyen',
#  'Ashley King',
#  'Angela Stevenson',
#  'दिपकस्वर पाण्डे',
#  'Joseph Carter',
#  'श्री योगेन्द्र सिंह',
#  'Christopher West',
#  'शशी रसाइली',
#  'Kevin Lynch',
#  'श्रीमती जयश्री (श्रेष्\u200dठ)',
#  'श्रद्धा राजकर्णिकार',
#  'Jason Steele',
#  'Laura Hines',
#  'Jose Diaz',
#  'राम तिवारी',
#  'धनमाया थापा',
#  'Sabrina Bender',
#  'Charles Jackson',
#  'फणिन्द्र डंगोल',
#  'विवेक पन्\u200dत',
#  'शिला प्याकुरेल',
#  'रविन बेगानी',
#  'Ricardo Harvey',
#  'प्रतिभा न्यौपाने',
#  'इन्\u200dद्र मोक्तान',
#  'हरि शाह',
#  'हरि मानन्धर',
#  'Shannon Perry',
#  'Theresa Conner',
#  'बनवारी गुरुङ',
#  'असिन आलम',
#  'Adrian Sellers Jr.',
#  'श्रीमान अविनाश लामा',
#  'Anthony Kaiser',
#  'सचिता गोयल',
#  'Maria Ward',
#  'श्री विजेश पौडेल',
#  'Gregory Gonzales',
#  'तुलसी देउजा',
#  'Jennifer Bailey',
#  'Anthony Taylor',
#  'सुश्री प्रतिभा रसायली',
#  'Erica Wood',
#  'Patricia Brown',
#  'डोली चौलागाई',
#  'मदन प्रधानाङ',
#  'राजु जैन',
#  'Jason Knox',
#  'Jonathan Maddox',
#  'चन्दा मैनाली',
#  'Brett Burke',
#  'Jennifer Owens',
#  'Brian Vazquez',
#  'Amber Payne',
#  'श्री छवि पन्त',
#  'बद्री बस्नेत',
#  'Kimberly Carter',
#  'फौजिया खनाल',
#  'Lisa Pierce',
#  'श्\u200dयामराज खत्री',
#  'Andrea Thornton',
#  'चन्दा शाह',
#  'Kristy Middleton',
#  'मनोज तुलाधर',
#  'Andrew Holder',
#  'देव सि\u200cह',
#  'Anne Smith MD',
#  'Michael Ferrell',
#  'राजु लामा',
#  'दिपक मानन्\u200dधर',
#  'शशी सिंघल',
#  'नारन राजकर्णिकार',
#  'रोहन के.सी.',
#  'Rodney White',
#  'राम चालिसे',
#  'धन्जु शाह',
#  'अंगुर मानन्धर',
#  'कृष्ण श्रेष्\u200dठ',
#  'जतन रेग्मी',
#  'Raven Cain',
#  'Erin Thompson',
#  'Larry Young',
#  'हिरा नेपाल',
#  'वुष्\u200dकर श्रेष्ठ',
#  'मदन चौलागाई',
#  'Elizabeth Sullivan',
#  'अनिष तिवारी',
#  'Justin Graham',
#  'शशी खनाल',
#  'Eugene Harris',
#  'Laura Gray',
#  'कविता जैन',
#  'Alexandra Li',
#  'योगेन्द्र मित्तल',
#  'नारायण कुइकेल',
#  'Sherry Adams',
#  'Hayley Mendez',
#  'Anne Mathis',
#  'Kimberly Castillo',
#  'Shawn Tucker',
#  'नविन भिमसरिया',
#  'सर्मिला प्रधानाङ्ग',
#  'हरि श्रेष्\u200dठ',
#  'Chelsea Moore',
#  'Lisa Mitchell',
#  'Jennifer Kim',
#  'Brett Andersen',
#  'Jack Allen',
#  'Kathleen Davis',
#  'मनोहर श्रेष्ठ',
#  'इन्दिरा श्रेष्\u200dठ',
#  'Alyssa Weber',
#  'Gregory Murillo',
#  'निरा अग्रवाल',
#  'श्रीमती भारती पौडेल',
#  'Samuel Ruiz',
#  'देवेन्द्र मानन\u200dधर',
#  'सुश्री चुरीनानी श्रेष्\u200dठ',
#  'तोप्ला कक्षपती',
#  'Christopher Lewis',
#  'Julia Harrell',
#  'Michelle Davis',
#  'सबनम राजकर्णिकार',
#  'Erin Smith',
#  'Jill Hayes',
#  'संजय कार्की',
#  'किरण रसाइली',
#  'सुष्\u200dमा वज्राचार्य',
#  'पासाङ्ग पनेरु',
#  'रामशरण शाह',
#  'Karen Sutton',
#  'Logan Hodge',
#  'फणिन्द्र थापा',
#  'Sue Evans',
#  'केशरी राजकर्णिकार',
#  'Thomas Woodard',
#  'दिनेस श्रेष्\u200dठ',
#  'Betty Kelly',
#  'दिपीन के.सी.',
#  'Jessica Diaz',
#  'पुष्\u200dप अग्रवाल',
#  'रामचन्द्र श्रेष्\u200dठ',
#  'Veronica Nguyen',
#  'नाती खड्गी',
#  'दमोदर गुरुङ्ग',
#  'Tiffany Mueller',
#  'Charlotte Campbell',
#  'Nicole Anderson',
#  'Heather Gilbert',
#  'शंकर श्रेष्ठ',
#  'रवि गुरुङ्ग',
#  'सजेन्\u200dद्र वज्राचार्य',
#  'पुन श्रेष्\u200dठ',
#  'William Cantu',
#  'छुङड्याक जोशी',
#  'Laura Fisher',
#  'श्रीजङ्ग मानन्धर',
#  'Nicole Clay',
#  'शचिन्द्र रेग्मी',
#  'Anthony Murphy',
#  'श्री सुनिल सुनुवार',
#  'सिता पराजुली',
#  'स्मृती गुरुङ्ग',
#  'Kimberly Evans',
#  'सुमित्रा अग्रवाल',
#  'बबि तिवारी',
#  'Jamie Davis',
#  'हिरा दुगड',
#  'अजय लोहनी',
#  'श्रीमती निलु गुरुङ',
#  'George Baldwin',
#  'विजया शाही',
#  'Steve Mann',
#  'प्रशान्त आचार्य',
#  'Craig Perry',
#  'Dale Smith',
#  'Collin Allen',
#  'विनिता शर्मा',
#  'रमा के.सी.',
#  'सुजन जैन',
#  'सविना पन्त',
#  'Jordan Bennett',
#  'Michael Reyes',
#  'Debra White',
#  'Sheri Roberts',
#  'Brandon Cunningham',
#  'Ronald Turner',
#  'Emily White',
#  'श्रीमान विजय मास्के',
#  'Marissa Johnson',
#  'Melissa Johnson',
#  'Kimberly Johnson',
#  'श्रीमती मिरा आलम',
#  'Patricia Hill',
#  'Paul Ramos',
#  'Katelyn Lopez']

# %%
fake.first_name_male()
# Out:
# 'राजेन्द्र'
