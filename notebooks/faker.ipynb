# %%
from faker import Faker
fake = Faker(['ne_NP', 'en_US'])

# %%
names = [fake.unique.name_male() for i in range(500)]

# %%
names
# Out:
# ['मनोहर श्रेष्\u200dठ',
#  'हिरा किराँत',
#  'टासी श्रेष्\u200dठ',
#  'भरत अधिकारी',
#  'Brett Allen',
#  'बुद्धि के.सी',
#  'राजेन्द्र तिवारी',
#  'Thomas Glass',
#  'Aaron Smith',
#  'पुरुषोत्तम श्रेष्\u200dठ',
#  'प्रकाश शाह',
#  'उत्तम गुरुङ्ग',
#  'Cameron Hall',
#  'एक खत्री',
#  'Mike Jacobs',
#  'सन्तोष क्षेत्री',
#  'Nathan Kim',
#  'Andrew Thompson II',
#  'Timothy Vaughn',
#  'राजु गोयल',
#  'Steve Smith',
#  'श्रीमान नवराज आलम',
#  'राजेश मानन्धर',
#  'शचिन्द्र (क्षेत्री)',
#  'आशिष अधिकारी',
#  'किरण लोहनी',
#  'सरोज अग्रवाल',
#  'शुशान्त सत्याल',
#  'टेक र\u200cजितकार',
#  'Michael Flowers',
#  'Stanley Jackson',
#  'सुदन जोशी',
#  'मोती गुरागाई',
#  'जगन्नाथ श्रेष्ठ',
#  'Robert Allison',
#  'श्रीमान मुरारीलाल श्रेष्\u200dठ',
#  'Frank Curtis',
#  'Robert Salazar',
#  'Christopher Riley',
#  'Richard Wong',
#  'Jay Ford',
#  'Robert Strickland',
#  'Thomas King',
#  'Travis Soto',
#  'John Lopez',
#  'श्री असोक पाण्डे',
#  'रविन्द्र गिरी',
#  'Nicholas Ramos',
# ...

# %%
fake.first_name_male()
# Out:
# 'राजेन्द्र'
